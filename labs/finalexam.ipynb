# %% [markdown]
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rlape2/rocksnot/blob/main/labs/finalexam.ipynb)

# %%
import rocksnot
import folium
# Out:
# /Users/robbylape/opt/anaconda3/envs/geowu/lib/python3.9/site-packages/fastkml/config.py:28: UserWarning: Package `lxml` missing. Pretty print will be disabled
#   warnings.warn("Package `lxml` missing. Pretty print will be disabled")

# %%
jsoncity = 'data/world_cities (1).csv'

# %%
shapecity = 'data/world_cities (1).csv'

# %%
rocksnot.csv_to_geojson(jsoncity, 'data/worldcity')

# %%
rocksnot.csv_to_shp(shapecity, 'data/worldcityshape')

# %%
#CSV to Geojson 

m = rocksnot.Map()
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %%
m.add_geojson('data/worldcity')

# %%
#CSV to shapefile
map = rocksnot.Map()
map
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %%
map.add_shp('data/worldcityshape')

# %%
#Create Marker Cluster

m = folium.Map(location=[40.77502, -111.93005], zoom_start=4)

# add the points from a CSV file to the map
m.add_points_from_csv('data/world_cities (1).csv', x='longitude', y='latitude', label='name')

# display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
